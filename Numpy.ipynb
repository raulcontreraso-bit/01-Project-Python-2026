# %%
# Without Numpy
a = [1,2,3,4, 5]
b = [10,11,12,13,14,15]
a + b 
result = [ ] 
for first , second in zip(a, b):    
    result.append(first + second ) 
print(result)
# Out:
# [11, 13, 15, 17, 19]

# %%
import  numpy as np

a = np.array([1,2,3,4])
type(a)


a.dtype
# Out:
# dtype('int64')

# %%
f = np.array( [1.2, 2.3, 4.5, 6.7 ])


f.dtype


a[0] = 7.4
#print(a)
a.ndim
#a.shape
# Out:
# 1

# %%
a + f
# Out:
# array([ 8.2,  4.3,  7.5, 10.7])

# %%
# Universal Functions (ufuncs)
np.sin(a)
# Out:
# array([ 0.6569866 ,  0.90929743,  0.14112001, -0.7568025 ])
