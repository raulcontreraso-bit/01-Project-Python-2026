# %%
import os
from flask import Flask, render_template, request, redirect
from werkzeug.utils import secure_filename # 1. Import this

app = Flask(__name__)
app.config['UPLOAD_FOLDER'] = 'uploads'

@app.route('/', methods=['GET', 'POST'])
def index():
    if request.method == 'POST':
        file = request.files['file']
        if file:
            # 2. Use secure_filename to clean the name
            filename = secure_filename(file.filename)
            
            # 3. Save using the 'safe' filename
            file.save(os.path.join(app.config['UPLOAD_FOLDER'], filename))
            
            # 4. Save the safe name to the database
            conn = sqlite3.connect('database.db')
            conn.execute('INSERT INTO images (filename) VALUES (?)', (filename,))
            conn.commit()
            conn.close()
            return redirect('/')
    return render_template('index.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from flask import Flask, render_template, request, redirect
#       3 from werkzeug.utils import secure_filename # 1. Import this
#       4
#       5 app = Flask(__name__)
#
# ModuleNotFoundError: No module named 'flask'
