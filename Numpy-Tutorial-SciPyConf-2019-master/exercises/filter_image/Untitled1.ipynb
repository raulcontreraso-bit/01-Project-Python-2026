# %%
from pathlib import Path

# The .. tells Python to go BACK one folder first
exercise_dir = Path("../EX1")

# %cd $exercise_dir
# %pwd
# Out:
# [WinError 2] El sistema no puede encontrar el archivo especificado: '..\\EX1'
# C:\Users\raulc\Documents\GitHub\01-Project-Python-2026\Numpy-Tutorial-SciPyConf-2019-master\exercises\filter_image
# 'C:\\Users\\raulc\\Documents\\GitHub\\01-Project-Python-2026\\Numpy-Tutorial-SciPyConf-2019-master\\exercises\\filter_image'
