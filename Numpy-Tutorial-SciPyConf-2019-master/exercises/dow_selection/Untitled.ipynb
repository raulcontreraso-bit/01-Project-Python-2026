# %%
from pathlib import Path

# Create a path variable pointing to your exercise folder
#exercise_dir = Path("exercises/dow_selection")
exercise_dir = Path("exercises/filter_image")

# %pwd
#%load filter_image_solution.py
# Out:
# 'C:\\Users\\raulc\\Documents\\GitHub\\01-Project-Python-2026\\Numpy-Tutorial-SciPyConf-2019-master\\exercises\\dow_selection'
